# %% [markdown]
# Exploring and Preprocessing the Data

# %% [markdown]
# BABALOLA ABDULHAFEEZ OLUWABUNMI
# START TECH ACADEMY
# TASK 2 MACHINE LEARNING
# QUESTION:
# My task is to help John from STA IT services to create a linear regression model in Python or R to predict the CTC/Salary of new hires from the data provided.

# %% [markdown]
# Import required libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %%
dataset = pd.read_excel('Data_file.xlsx', header = 2,index_col=0)
dataset
# Out:
#       Tier 2  Executive      Metro  57081  1  84  18  68005.87
# 2
# 3     Tier 2  Executive      Metro  60347  2  52  28  76764.02
# 4     Tier 3  Executive      Metro  49010  2  81  33  82092.39
# 5     Tier 3  Executive      Metro  57879  4  74  32  73878.10
# 6     Tier 2  Executive  Non-Metro  54340  4  73  31  59950.89
# 7     Tier 2  Executive  Non-Metro  60298  1  42  46  66602.34
# ...      ...        ...        ...    ... ..  ..  ..       ...
# 1334  Tier 3  Executive      Metro  59661  4  68  50  69712.40
# 1335  Tier 1  Executive  Non-Metro  53714  1  67  18  69298.75
# 1336  Tier 2  Executive  Non-Metro  61957  1  47  18  66397.77
# 1337  Tier 1  Executive  Non-Metro  53203  3  69  21  64044.38
# 1338  Tier 3    Manager  Non-Metro  51820  1  47  61  83346.06
#
# [1336 rows x 8 columns]

# %%
dataset.head()
# Out:
#    Tier 2  Executive      Metro  57081  1  84  18  68005.87
# 2
# 3  Tier 2  Executive      Metro  60347  2  52  28  76764.02
# 4  Tier 3  Executive      Metro  49010  2  81  33  82092.39
# 5  Tier 3  Executive      Metro  57879  4  74  32  73878.10
# 6  Tier 2  Executive  Non-Metro  54340  4  73  31  59950.89
# 7  Tier 2  Executive  Non-Metro  60298  1  42  46  66602.34

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1336 entries, 3 to 1338
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Tier 2     1336 non-null   object
#  1   Executive  1336 non-null   object
#  2   Metro      1336 non-null   object
#  3   57081      1336 non-null   int64
#  4   1          1336 non-null   int64
#  5   84         1336 non-null   int64
#  6   18         1336 non-null   int64
#  7   68005.87   1336 non-null   float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 93.9+ KB

# %%
dataset.describe()
# Out:
#               57081            1           84           18       68005.87
# count   1336.000000  1336.000000  1336.000000  1336.000000    1336.000000
# mean   55580.684132     2.526198    59.868263    39.238024   75467.951482
# std     6690.480514     1.123492    14.890281    14.037572   12558.528940
# min    36990.000000     1.000000    35.000000    18.000000   53020.320000
# 25%    50541.500000     2.000000    47.000000    27.000000   66901.767500
# 50%    55292.000000     3.000000    60.000000    39.000000   73141.150000
# 75%    60161.250000     4.000000    73.000000    51.000000   80766.547500
# max    77911.000000     4.000000    85.000000    64.000000  123416.990000

# %%
dataset.isnull().sum()
# Out:
# Tier 2       0
# Executive    0
# Metro        0
# 57081        0
# 1            0
# 84           0
# 18           0
# 68005.87     0
# dtype: int64

# %% [markdown]
# # Loading and Preprocessing the test data

# %%
test = pd.read_excel('C:\\Users\\USER\\Desktop\\STARTUP_TECH_INTERN\\data\\Test_data_file.xlsx')
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC  Predicted CTC
# 0  71406.57653            NaN
# 1  68005.87063            NaN
# 2  76764.02028            NaN
# 3  82092.38688            NaN
# 4  73878.09773            NaN

# %%
test.columns
# Out:
# Index(['College', 'Role', 'City type', 'College_T1', 'College_T2',
#        'Role_Manager', 'City_Metro', 'previous CTC', 'previous job changes',
#        'Graduation marks', 'Exp', 'Actual CTC', 'Predicted CTC'],
#       dtype='object')

# %%
test.drop(test.columns[14:23], axis=1, inplace=True)
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC  Predicted CTC
# 0  71406.57653            NaN
# 1  68005.87063            NaN
# 2  76764.02028            NaN
# 3  82092.38688            NaN
# 4  73878.09773            NaN

# %%
#del test['Unnamed: 13']
#del test['Unnamed: 23']

# %%
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC  Predicted CTC
# 0  71406.57653            NaN
# 1  68005.87063            NaN
# 2  76764.02028            NaN
# 3  82092.38688            NaN
# 4  73878.09773            NaN

# %%
#del test['Role']
#del test['College']
#del test['City type']
test.drop(labels='Role', axis=1)
# Out:
#      College  City type  College_T1  College_T2  Role_Manager  City_Metro  \
# 0     Tier 1  Non-Metro           1           0             1           0
# 1     Tier 2      Metro           0           1             0           1
# 2     Tier 2      Metro           0           1             0           1
# 3     Tier 3      Metro           0           0             0           1
# 4     Tier 3      Metro           0           0             0           1
# ...      ...        ...         ...         ...           ...         ...
# 1333  Tier 3      Metro           0           0             0           1
# 1334  Tier 1  Non-Metro           1           0             0           0
# 1335  Tier 2  Non-Metro           0           1             0           0
# 1336  Tier 1  Non-Metro           1           0             0           0
# 1337  Tier 3  Non-Metro           0           0             1           0
#
#       previous CTC  previous job changes  Graduation marks  Exp   Actual CTC  \
# 0            55523                     3                66   19  71406.57653
# 1            57081                     1                84   18  68005.87063
# 2            60347                     2                52   28  76764.02028
# 3            49010                     2                81   33  82092.38688
# 4            57879                     4                74   32  73878.09773
# ...            ...                   ...               ...  ...          ...
# 1333         59661                     4                68   50  69712.40366
# 1334         53714                     1                67   18  69298.75010
# 1335         61957                     1                47   18  66397.77069
# 1336         53203                     3                69   21  64044.38295
# 1337         51820                     1                47   61  83346.06096
#
#       Predicted CTC
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ...             ...
# 1333            NaN
# 1334            NaN
# 1335            NaN
# 1336            NaN
# 1337            NaN
#
# [1338 rows x 12 columns]

# %%
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC  Predicted CTC
# 0  71406.57653            NaN
# 1  68005.87063            NaN
# 2  76764.02028            NaN
# 3  82092.38688            NaN
# 4  73878.09773            NaN

# %% [markdown]
# Building a Linear Regression model

# %%
X = test[['previous CTC','previous job changes','Graduation marks','Exp','College_T1','College_T2','Role_Manager','City_Metro']]
Y = test[['Actual CTC']]

# %%
X
# Out:
#       previous CTC  previous job changes  Graduation marks  Exp  College_T1  \
# 0            55523                     3                66   19           1
# 1            57081                     1                84   18           0
# 2            60347                     2                52   28           0
# 3            49010                     2                81   33           0
# 4            57879                     4                74   32           0
# ...            ...                   ...               ...  ...         ...
# 1333         59661                     4                68   50           0
# 1334         53714                     1                67   18           1
# 1335         61957                     1                47   18           0
# 1336         53203                     3                69   21           1
# 1337         51820                     1                47   61           0
#
#       College_T2  Role_Manager  City_Metro
# 0              0             1           0
# 1              1             0           1
# 2              1             0           1
# 3              0             0           1
# 4              0             0           1
# ...          ...           ...         ...
# 1333           0             0           1
# 1334           0             0           0
# 1335           1             0           0
# 1336           0             0           0
# 1337           0             1           0
#
# [1338 rows x 8 columns]

# %%
Y
# Out:
#        Actual CTC
# 0     71406.57653
# 1     68005.87063
# 2     76764.02028
# 3     82092.38688
# 4     73878.09773
# ...           ...
# 1333  69712.40366
# 1334  69298.75010
# 1335  66397.77069
# 1336  64044.38295
# 1337  83346.06096
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state = 101)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, accuracy_score
regressor = LinearRegression()

# %% [markdown]
# Prediction of CTC/SALARY

# %%
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
prediction = regressor.predict(X)
test['Predicted CTC'] = prediction
test.head()
# Out:
#   College       Role  City type  College_T1  College_T2  Role_Manager  \
# 0  Tier 1    Manager  Non-Metro           1           0             1
# 1  Tier 2  Executive      Metro           0           1             0
# 2  Tier 2  Executive      Metro           0           1             0
# 3  Tier 3  Executive      Metro           0           0             0
# 4  Tier 3  Executive      Metro           0           0             0
#
#    City_Metro  previous CTC  previous job changes  Graduation marks  Exp  \
# 0           0         55523                     3                66   19
# 1           1         57081                     1                84   18
# 2           1         60347                     2                52   28
# 3           1         49010                     2                81   33
# 4           1         57879                     4                74   32
#
#     Actual CTC  Predicted CTC
# 0  71406.57653   85479.353475
# 1  68005.87063   66555.819928
# 2  76764.02028   70643.819779
# 3  82092.38688   67203.839421
# 4  73878.09773   70681.598118

# %%
prediction
# Out:
# array([[85479.35347546],
#        [66555.81992815],
#        [70643.81977858],
#        ...,
#        [65110.95620656],
#        [65772.64048568],
#        [91010.38463109]])

# %%
print(regressor.coef_)
# Out:
# [[ 4.71976444e-01 -2.68251107e+02 -1.07626878e+01  2.47036988e+02
#    3.83778686e+03 -9.87749595e+02  1.90735136e+04  4.14444031e+03]]

# %%
print(regressor.intercept_)
# Out:
# [33183.89288806]

# %%
predicted = regressor.predict(X_test)

# %%
print(X_test)
# Out:
#       previous CTC  previous job changes  Graduation marks  Exp  College_T1  \
# 44           66050                     1                35   38           1
# 134          53110                     4                43   20           1
# 980          46432                     3                61   54           1
# 618          63071                     2                60   19           0
# 1238         52099                     4                49   37           1
# ...            ...                   ...               ...  ...         ...
# 375          48909                     1                63   23           0
# 686          50105                     4                74   42           1
# 103          56680                     4                63   61           0
# 1137         43851                     1                65   26           0
# 714          46192                     1                45   24           1
#
#       College_T2  Role_Manager  City_Metro
# 44             0             0           1
# 134            0             0           0
# 980            0             0           1
# 618            1             1           0
# 1238           0             0           1
# ...          ...           ...         ...
# 375            0             1           0
# 686            0             0           1
# 103            1             1           0
# 1137           0             0           0
# 714            0             0           0
#
# [402 rows x 8 columns]

# %%
predicted.shape
# Out:
# (402, 1)

# %%
#dframe =pd.DataFrame(Y_test, predicted)
#dfr =pd.DataFrame({'Actual': Y_test, 'CTC':predicted})
Y_test
# Out:
#         Actual CTC
# 44     69116.92554
# 134    72322.79081
# 980   102860.45100
# 618    95369.34520
# 1238   66978.71550
# ...            ...
# 375    72988.31251
# 686    76594.04464
# 103    85688.72170
# 1137   54865.59334
# 714    61873.12367
#
# [402 rows x 1 columns]

# %%
predicted
# Out:
# array([[ 81082.62457163],
#        [ 65493.28846314],
#        [ 74959.65040478],
#        [ 84549.12245862],
#        [ 73295.61326146],
#        [ 66713.33192876],
#        [ 79264.6132895 ],
#        [ 62328.23880763],
#        [ 73358.27311174],
#        [ 70513.02391387],
#        [ 70819.45281895],
#        [ 72507.03725451],
#        [ 74490.92245318],
#        [ 77075.16463411],
#        [ 89701.45040704],
#        [ 93536.78018705],
#        [ 70606.82403437],
#        [ 62682.52463   ],
#        [ 86074.39226894],
#        [ 81821.10046606],
#        [ 82807.73656288],
#        [ 70675.32202611],
#        [ 76256.56908779],
#        [ 68876.66677251],
#        [ 68348.73923874],
#        [ 85479.35347546],
#        [ 70548.83068198],
#        [ 87840.32866663],
#        [ 93895.78652917],
#        [ 72353.49632478],
#        [ 63531.64609325],
#        [ 70474.68275119],
#        [ 65564.50174493],
#        [ 58820.97849754],
#        [ 65543.20359617],
#        [ 70777.70090987],
#        [ 65529.41160544],
#        [ 74508.00611693],
#        [ 76395.05443299],
#        [ 78830.78352361],
#        [ 73820.57912374],
#        [ 78490.8205703 ],
#        [ 84450.79168767],
#        [ 71529.5364851 ],
#        [ 67254.84843868],
#        [ 67552.76660681],
#        [ 75319.98496499],
#        [ 66865.31834706],
#        [ 72838.60673226],
#        [ 63118.78050373],
#        [ 62364.5653668 ],
#        [ 63396.89161203],
#        [ 65909.50431131],
#        [ 92489.44161522],
#        [ 71432.82279647],
#        [ 72314.16338332],
#        [ 74701.53465441],
#        [ 67152.9073557 ],
#        [ 93963.18342689],
#        [ 66131.0678344 ],
#        [ 66849.57588991],
#        [ 71638.88933289],
#        [ 70131.62997363],
#        [ 89406.28593707],
#        [ 70768.00459179],
#        [ 66890.97286892],
#        [ 70846.74976046],
#        [ 86346.42372222],
#        [ 87598.22564976],
#        [ 99253.24293332],
#        [ 67901.44270629],
#        [ 66475.28472959],
#        [ 77387.75421091],
#        [ 75025.91419191],
#        [ 65541.64810517],
#        [ 65933.21184099],
#        [ 94587.61494123],
#        [ 78619.97515072],
#        [ 74060.59057513],
#        [ 71640.85224944],
#        [ 67087.01943225],
#        [ 73721.88006543],
#        [ 66666.25501672],
#        [ 64221.30390448],
#        [ 71298.79639389],
#        [ 75675.18939496],
#        [ 75424.70767971],
#        [ 98857.5460184 ],
#        [ 66722.02952127],
#        [ 70520.34084915],
#        [ 73285.07791153],
#        [ 64766.27003304],
#        [ 73295.48022764],
#        [ 66942.51578524],
#        [ 72068.71617572],
#        [ 69918.74173403],
#        [ 73457.24181589],
#        [ 97078.08642711],
#        [ 71242.20624832],
#        [ 63484.35741815],
#        [ 82338.14681603],
#        [ 70650.61738478],
#        [ 76954.81888559],
#        [ 66579.04973613],
#        [ 86990.02890641],
#        [ 78041.107753  ],
#        [ 73714.40984458],
#        [ 74560.79093439],
#        [ 92315.68124754],
#        [ 65349.97052955],
#        [ 69123.33828493],
#        [ 72071.00297958],
#        [ 69117.07119346],
#        [ 66048.59976045],
#        [ 75941.98206818],
#        [ 66476.55181252],
#        [ 74060.40226775],
#        [ 75505.60145766],
#        [ 83081.00711359],
#        [ 96874.17049241],
#        [ 64757.44025631],
#        [ 66131.28407948],
#        [ 75815.43746489],
#        [ 66115.17118887],
#        [ 63400.81362921],
#        [ 79052.48094489],
#        [ 69060.90747763],
#        [ 74093.79783759],
#        [ 70796.48250466],
#        [ 74036.43574602],
#        [ 75205.85400185],
#        [ 76378.80027969],
#        [ 69645.01138692],
#        [ 77167.48595156],
#        [101228.65025384],
#        [ 73591.4567124 ],
#        [ 78659.81003244],
#        [ 84655.56830182],
#        [ 64994.98475285],
#        [101736.69017896],
#        [ 71651.35884556],
#        [ 79617.61607993],
#        [ 70842.47768493],
#        [ 63819.66000546],
#        [ 76032.6600923 ],
#        [ 64936.88104428],
#        [ 85967.48083841],
#        [ 71902.67583027],
#        [ 67660.26488747],
#        [ 88215.84629167],
#        [ 73911.1910007 ],
#        [ 60605.21370185],
#        [ 80076.85264625],
#        [ 73320.60997884],
#        [ 91339.48423144],
#        [ 59335.66782804],
#        [ 63999.53131869]])

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
regressor.score(X_test,Y_test)
# Out:
# 0.6029224845005943

# %%
import math
import sklearn.metrics as metrics

# %%
print('Mean Absolute Error:', metrics.mean_absolute_error(Y_test,predicted))
# Out:
# Mean Absolute Error: 6210.390550761868

# %%
print('Mean Squared Error:', metrics.mean_squared_error(Y_test,predicted))
# Out:
# Mean Squared Error: 62755406.24580518

# %% [markdown]
# MEAN SQUARED ERROR

# %%
print('Root Mean Squared Error:', math.sqrt(metrics.mean_squared_error(Y_test,predicted)))
# Out:
# Root Mean Squared Error: 7921.830990737254
